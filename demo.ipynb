# %% [markdown]
# # Libraries

# %%
import torch
import os
import glob
from IPython.display import Image, display

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.2 (CPU)

# %%
# !python prepare.py
# Out:
# 100%|███████████████████████████████████████| 853/853 [00:00<00:00, 1793.77it/s]

# %% [markdown]
# # Train YOLOv5 model

# %%
# %cd yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data ../mask_config.yaml --weights yolov5s.pt --workers 0

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance
# Training losses and performance metrics are saved in runs folder

# %%
from utils.plots import plot_results
plot_results('runs/train/exp/results.csv')

# %% [markdown]
# ### Prediction on Images

# %%
# !python detect.py --source ../datasets/mask/valid/images/ --weights runs/train/exp/weights/best.pt --conf 0.2
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../datasets/mask/valid/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-21-ge6e36aa torch 1.10.2 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/171 /Users/selmee/Projects/yolov5-mask-detection/datasets/mask/valid/images/maksssksksss125.png: 640x512 1 without_mask, Done. (0.252s)
# image 2/171 /Users/selmee/Projects/yolov5-mask-detection/datasets/mask/valid/images/maksssksksss135.png: 384x640 2 with_masks, 2 without_masks, Done. (0.176s)
# ...

# %%
#display inference on some test images
images = glob.glob('runs/detect/exp12/*.png')

for imageName in images[:3]: #assuming JPG
    display(Image(filename=imageName, width=400))

# %% [markdown]
# ### Prediction on Video

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../datasets/input.mp4

# %%
import cv2
vidcap = cv2.VideoCapture('runs/detect/exp2/input.mp4')
success,image = vidcap.read()
images = []
while success:
    success,image = vidcap.read()
    if success:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        images.append(image)

# %%
from matplotlib import animation, rc
import matplotlib.pyplot as plt

rc('animation', html='jshtml')

def create_animation(ims):
    fig = plt.figure(figsize=(9, 9))
    plt.axis('off')
    im = plt.imshow(ims[0])

    def animate_func(i):
        im.set_array(ims[i])
        return [im]

    return animation.FuncAnimation(fig, animate_func, frames = len(ims), interval = 1000//12)

create_animation(images)
